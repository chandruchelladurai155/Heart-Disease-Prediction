# %% [markdown]
# # Heart Disease Prediction
#
# This notebook walks through loading the heart disease dataset, exploring the data, training a model, and evaluating its performance.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from src.data_loader import load_heart_disease_data
from src.model_training import build_pipeline, evaluate_model, train_model

sns.set(style="whitegrid")

# %% [markdown]
# ## Load the dataset

# %%
df = load_heart_disease_data()
df.head()

# %% [markdown]
# ## Dataset shape and target distribution

# %%
print("Shape:", df.shape)
print("Target distribution:")
print(df["target"].value_counts(normalize=True))

# %%
plt.figure(figsize=(6, 4))
sns.countplot(x="target", data=df)
plt.title("Heart Disease Target Distribution")
plt.xlabel("Heart Disease (0 = No, 1 = Yes)")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ## Feature correlations

# %%
plt.figure(figsize=(12, 10))
corr = df.corr()
sns.heatmap(corr, annot=True, fmt=".2f", cmap="coolwarm")
plt.title("Correlation matrix for heart disease features")
plt.show()

# %% [markdown]
# ## Train a model

# %%
model, X_test, y_test = train_model(df)
metrics = evaluate_model(model, X_test, y_test)
print("Accuracy:", metrics['accuracy'])
print(metrics['classification_report'])

# %% [markdown]
# ## Confusion matrix

# %%
cm = metrics['confusion_matrix']
plt.figure(figsize=(5, 4))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %% [markdown]
# ## Next steps
#
# - Try different classifiers such as `LogisticRegression`, `XGBClassifier`, or `GradientBoostingClassifier`.
# - Perform feature engineering on categorical variables.
# - Tune hyperparameters using `GridSearchCV` or `RandomizedSearchCV`.
# - Add a prediction API or Streamlit app for interactive use.
